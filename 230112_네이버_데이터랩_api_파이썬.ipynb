# %% [markdown]
# <a href="https://colab.research.google.com/github/SohyunKimmm/SohyunKimmm/blob/main/230112_%EB%84%A4%EC%9D%B4%EB%B2%84_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%9E%A9_api_%ED%8C%8C%EC%9D%B4%EC%8D%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import urllib.request
import json

#접속해서 들어가기
client_id = "64J7PO6G9kbeeVR_PpCj"
client_secret = "XfggZ7TSz8"

url = "https://openapi.naver.com/v1/datalab/search"
body = "{\
         \"startDate\":\"2022-12-01\",\
         \"endDate\":\"2023-01-26\",\
         \"timeUnit\":\"date\",\
         \"keywordGroups\":[{\"groupName\":\"삼성\",\"keywords\":[\"삼성\",\"samsung\"]}],\
         \"device\":\"pc\",\
         \"ages\":[\"1\",\"2\"],\
         \"gender\":\"f\"\
         }";

#네이버에 저장되어있는 형식코드를 받아서 데이터프레임에 맞춰서 분해하는 작업
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")

response = urllib.request.urlopen(request, data=body.encode("utf-8"))

rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    response_data = response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)

result = json.loads(response_data)

print(result)

date = [a['period'] for a in result['results'][0]['data']]
ratio_data1 = [a['ratio'] for a in result['results'][0]['data']]


pd.DataFrame({'date':date,
        'seraching_result':ratio_data1})
# Out:
# {'startDate': '2022-12-01', 'endDate': '2023-01-26', 'timeUnit': 'date', 'results': [{'title': '삼성', 'keywords': ['삼성', 'samsung'], 'data': [{'period': '2022-12-01', 'ratio': 57.14285}, {'period': '2022-12-02', 'ratio': 61.90476}, {'period': '2022-12-03', 'ratio': 21.42857}, {'period': '2022-12-04', 'ratio': 45.23809}, {'period': '2022-12-05', 'ratio': 76.19047}, {'period': '2022-12-06', 'ratio': 66.66666}, {'period': '2022-12-07', 'ratio': 73.80952}, {'period': '2022-12-08', 'ratio': 73.80952}, {'period': '2022-12-09', 'ratio': 42.85714}, {'period': '2022-12-10', 'ratio': 64.28571}, {'period': '2022-12-11', 'ratio': 61.90476}, {'period': '2022-12-12', 'ratio': 57.14285}, {'period': '2022-12-13', 'ratio': 42.85714}, {'period': '2022-12-14', 'ratio': 66.66666}, {'period': '2022-12-15', 'ratio': 100}, {'period': '2022-12-16', 'ratio': 69.04761}, {'period': '2022-12-17', 'ratio': 66.66666}, {'period': '2022-12-18', 'ratio': 78.57142}, {'period': '2022-12-19', 'ratio': 85.71428}, {'perio
# ...
